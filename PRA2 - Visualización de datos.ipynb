# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import pyplot

# %%
df16_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_16.csv',low_memory=False)
df17_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_17.csv',low_memory=False)
df18_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_18.csv',low_memory=False)
df19_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_19.csv',low_memory=False)
df20_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_20.csv',low_memory=False)
df21_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_21.csv',low_memory=False)
df22_m = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\players_22.csv',low_memory=False)
df16_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_16.csv',low_memory=False)
df17_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_17.csv',low_memory=False)
df18_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_18.csv',low_memory=False)
df19_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_19.csv',low_memory=False)
df20_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_20.csv',low_memory=False)
df21_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_21.csv',low_memory=False)
df22_f = pd.read_csv(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 1\archive\\female_players_22.csv',low_memory=False)
df16_m.shape
# Out:
# (15623, 110)

# %%
list_dataframes_males = [df16_m,df17_m,df18_m,df19_m,df20_m,df21_m,df22_m]
males = pd.concat(list_dataframes_males, ignore_index=True, axis=0, join='outer')
males['gender'] = 'Male'

# %%
list_dataframes_females = [df16_f,df17_f,df18_f,df19_f,df20_f,df21_f,df22_f]
females = pd.concat(list_dataframes_females, ignore_index=True, axis=0, join='outer')
females['gender'] = 'Female'

# %%
columnas = males.columns.to_list()
columnas
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'player_positions',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'club_team_id',
#  'club_name',
#  'league_name',
#  'league_level',
#  'club_position',
#  'club_jersey_number',
#  'club_loaned_from',
#  'club_joined',
#  'club_contract_valid_until',
#  'nationality_id',
#  'nationality_name',
#  'nation_team_id',
#  'nation_position',
#  'nation_jersey_number',
#  'preferred_foot',
#  'weak_foot',
#  'skill_moves',
#  'international_reputation',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'player_traits',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
# ...

# %%
players = pd.read_excel(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 2\\Jugadores nacionales.xlsx')

# %%
players
# Out:
#         short_name Equipo nacional  Resultado numerico  Resultado final
# 0          A. Long   United States                   1  Octavofinalista
# 1          A. Mooy       Australia                   1  Octavofinalista
# 2      A. Ramsdale         England                   2  Cuartofinalista
# 3    A. Ezzalzouli         Morocco                   3    Semifinalista
# 4        A. Sabiri         Morocco                   3    Semifinalista
# ..             ...             ...                 ...              ...
# 409      Y. Sabaly         Senegal                   1  Octavofinalista
# 410        Y. Soma           Japan                   1  Octavofinalista
# 411       Y. Musah   United States                   1  Octavofinalista
# 412    Y. Nagatomo           Japan                   1  Octavofinalista
# 413      Z. Labyad         Morocco                   3    Semifinalista
#
# [414 rows x 4 columns]

# %%
lista_paises_fase_final = list(set(players['Equipo nacional']))
# Out:
#         sofifa_id                                         player_url  \
# 0          158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2            9014  https://sofifa.com/player/9014/arjen-robben/16...
# 7              41  https://sofifa.com/player/41/andres-iniesta-lu...
# 8          164240  https://sofifa.com/player/164240/thiago-emilia...
# ...           ...                                                ...
# 125868     255336  https://sofifa.com/player/255336/fred-emmings/...
# 125869     255553  https://sofifa.com/player/255553/seong-yoon-kw...
# 125881     260474  https://sofifa.com/player/260474/bong-soo-kim/...
# 125882     260635  https://sofifa.com/player/260635/jalen-neal/22...
# 125901     263340  https://sofifa.com/player/263340/harvey-wiles-...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
males['nationality_name']
lista_paises_fase_final
# Out:
# ['Morocco',
#  'Australia',
#  'Poland',
#  'England',
#  'Senegal',
#  'Argentina',
#  'Spain',
#  'Switzerland',
#  'Portugal',
#  'Brazil',
#  'France',
#  'Japan',
#  'Netherlands',
#  'Croatia',
#  'United States',
#  'Korea Republic']

# %%
for pais in sorted(lista_paises_fase_final):
    print()
    print(pais)
    print(sorted(set(males[males['nationality_name']== pais]['short_name'].to_list())))
# Out:
# Argentina
# ...

# %%
df22_m
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
final = pd.merge(df22_m,players,on='short_name',how='left')

# %%
final
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19237     261962  https://sofifa.com/player/261962/defu-song/220002
# 19238     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19239     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19240     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19241     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
final['Resultado numerico'].value_counts()
# Out:
# 1.0    202
# 2.0     98
# 3.0     40
# 5.0     35
# 4.0     25
# Name: Resultado numerico, dtype: int64

# %%
final_2 = final[['short_name','overall','potential','value_eur','wage_eur','age','height_cm','weight_kg','league_name',
                'nationality_name','pace','club_name',
                 'shooting',
                 'passing',
                 'dribbling',
                 'defending',
                 'physic',
                 'attacking_crossing',
                 'attacking_finishing',
                 'attacking_heading_accuracy',
                 'attacking_short_passing',
                 'attacking_volleys',
                 'skill_dribbling',
                 'skill_curve',
                 'skill_fk_accuracy',
                 'skill_long_passing',
                 'skill_ball_control',
                 'movement_acceleration',
                 'movement_sprint_speed',
                 'movement_agility',
                 'movement_reactions',
                 'movement_balance',
                 'power_shot_power',
                 'power_jumping',
                 'power_stamina',
                 'power_strength',
                 'power_long_shots',
                 'mentality_aggression',
                 'mentality_interceptions',
                 'mentality_positioning',
                 'mentality_vision',
                 'mentality_penalties',
                 'mentality_composure',
                 'defending_marking_awareness',
                 'defending_standing_tackle',
                 'defending_sliding_tackle',
                 'goalkeeping_diving',
                 'goalkeeping_handling',
                 'goalkeeping_kicking',
                 'goalkeeping_positioning',
                 'goalkeeping_reflexes',
                 'goalkeeping_speed','Equipo nacional','Resultado numerico','Resultado final']]

# %%
final_2.describe(include="all")
# Out:
#           short_name       overall     potential     value_eur       wage_eur  \
# count          19242  19242.000000  19242.000000  1.916800e+04   19181.000000
# unique         18145           NaN           NaN           NaN            NaN
# top     J. Rodríguez           NaN           NaN           NaN            NaN
# freq              13           NaN           NaN           NaN            NaN
# mean             NaN     65.773984     71.080865  2.855442e+06    9025.598248
# std              NaN      6.881771      6.087977  7.634115e+06   19493.473716
# min              NaN     47.000000     49.000000  9.000000e+03     500.000000
# 25%              NaN     61.000000     67.000000  4.750000e+05    1000.000000
# 50%              NaN     66.000000     71.000000  9.750000e+05    3000.000000
# 75%              NaN     70.000000     75.000000  2.000000e+06    8000.000000
# max              NaN     93.000000     95.000000  1.940000e+08  350000.000000
#
# ...

# %%
final_3 = final_2[final_2['Resultado final'].notna()]

# %%
final_3
# Out:
#               short_name  overall  potential    value_eur  wage_eur  age  \
# 0               L. Messi       93         93   78000000.0  320000.0   34
# 1         R. Lewandowski       92         92  119500000.0  270000.0   32
# 2      Cristiano Ronaldo       91         91   45000000.0  270000.0   36
# 6              K. Mbappé       91         95  194000000.0  230000.0   22
# 9                H. Kane       90         90  129500000.0  240000.0   27
# ...                  ...      ...        ...          ...       ...  ...
# 17765          Z. Labyad       56         64     325000.0    1000.0   21
# 18521         A. Jashari       53         71     240000.0     800.0   18
# 18584        A. Robinson       53         58     140000.0     500.0   24
# 18645          C. Wilson       53         70     240000.0     850.0   18
# 18663          H. Wright       52         62     160000.0    1000.0   22
#
#        height_cm  weight_kg                     league_name  \
# ...

# %%
final_4 = final_3.groupby(['Equipo nacional','Resultado final'])[['overall','potential','value_eur','wage_eur','age','height_cm','weight_kg',
                'pace',
                 'shooting',
                 'passing',
                 'dribbling',
                 'defending',
                 'physic',
                 'attacking_crossing',
                 'attacking_finishing',
                 'attacking_heading_accuracy',
                 'attacking_short_passing',
                 'attacking_volleys',
                 'skill_dribbling',
                 'skill_curve',
                 'skill_fk_accuracy',
                 'skill_long_passing',
                 'skill_ball_control',
                 'movement_acceleration',
                 'movement_sprint_speed',
                 'movement_agility',
                 'movement_reactions',
                 'movement_balance',
                 'power_shot_power',
                 'power_jumping',
                 'power_stamina',
                 'power_strength',
                 'power_long_shots',
                 'mentality_aggression',
                 'mentality_interceptions',
                 'mentality_positioning',
                 'mentality_vision',
                 'mentality_penalties',
                 'mentality_composure',
                 'defending_marking_awareness',
                 'defending_standing_tackle',
                 'defending_sliding_tackle',
                 'goalkeeping_diving',
                 'goalkeeping_handling',
                 'goalkeeping_kicking',
                 'goalkeeping_positioning',
                 'goalkeeping_reflexes',
                 'goalkeeping_speed','Resultado numerico','Resultado final']].mean()

# %%
final_4
# Out:
#                                    overall  potential     value_eur  \
# Equipo nacional Resultado final
# Argentina       Campeon          77.085714  80.771429  2.277786e+07
# Australia       Octavofinalista  69.576923  72.807692  2.778261e+06
# Brazil          Cuartofinalista  78.368421  82.473684  3.556579e+07
# Croatia         Semifinalista    75.916667  80.250000  1.512500e+07
# England         Cuartofinalista  77.000000  81.882353  3.572397e+07
# France          Subcampeon       80.520000  84.960000  3.835000e+07
# Japan           Octavofinalista  70.838710  74.000000  4.515645e+06
# Korea Republic  Octavofinalista  71.062500  73.687500  3.245312e+06
# Morocco         Semifinalista    72.500000  76.437500  1.212500e+07
# Netherlands     Cuartofinalista  76.962963  81.888889  2.653981e+07
# Poland          Octavofinalista  73.800000  78.440000  1.321087e+07
# Portugal        Cuartofinalista  78.444444  82.888889  3.073944e+07
# ...

# %%
normalized_final_4 = (final_4-final_4.min())/(final_4.max()-final_4.min())

# %%
normalized_final_4
# Out:
#                                   overall  potential  value_eur  wage_eur  \
# Equipo nacional Resultado final
# Argentina       Campeon          0.686168   0.655327   0.562233  0.463782
# Australia       Octavofinalista  0.000000   0.000000   0.000000  0.000000
# Brazil          Cuartofinalista  0.803384   0.795404   0.921730  0.978196
# Croatia         Semifinalista    0.579338   0.612419   0.347094  0.414438
# England         Cuartofinalista  0.678335   0.746744   0.926177  0.945526
# France          Subcampeon       1.000000   1.000000   1.000000  1.000000
# Japan           Octavofinalista  0.115305   0.098114   0.048842  0.100935
# Korea Republic  Octavofinalista  0.135755   0.072398   0.013130  0.044106
# Morocco         Semifinalista    0.267117   0.298693   0.262757  0.278312
# Netherlands     Cuartofinalista  0.674951   0.747282   0.667990  0.563842
# Poland          Octavofinalista  0.385913   0.463476   0.293284  0.321318
# ...

# %%
normalized_final_4.reset_index(drop=False, inplace=True)

# %%
normalized_final_4
# Out:
#    Equipo nacional  Resultado final   overall  potential  value_eur  wage_eur  \
# 0        Argentina          Campeon  0.686168   0.655327   0.562233  0.463782
# 1        Australia  Octavofinalista  0.000000   0.000000   0.000000  0.000000
# 2           Brazil  Cuartofinalista  0.803384   0.795404   0.921730  0.978196
# 3          Croatia    Semifinalista  0.579338   0.612419   0.347094  0.414438
# 4          England  Cuartofinalista  0.678335   0.746744   0.926177  0.945526
# 5           France       Subcampeon  1.000000   1.000000   1.000000  1.000000
# 6            Japan  Octavofinalista  0.115305   0.098114   0.048842  0.100935
# 7   Korea Republic  Octavofinalista  0.135755   0.072398   0.013130  0.044106
# 8          Morocco    Semifinalista  0.267117   0.298693   0.262757  0.278312
# 9      Netherlands  Cuartofinalista  0.674951   0.747282   0.667990  0.563842
# 10          Poland  Octavofinalista  0.385913   0.463476   0.293284  0.321318
# ...

# %%
correlacion_resultados = normalized_final_4[normalized_final_4.columns[2:]].corr()['Resultado numerico']
correlacion_resultados
# Out:
# overall                        0.544352
# potential                      0.461933
# value_eur                      0.436819
# wage_eur                       0.379428
# age                           -0.059314
# height_cm                      0.046469
# weight_kg                      0.013337
# pace                          -0.046851
# shooting                       0.496135
# passing                        0.460143
# dribbling                      0.474823
# defending                      0.277539
# physic                         0.208458
# attacking_crossing             0.333790
# attacking_finishing            0.495392
# attacking_heading_accuracy     0.583079
# attacking_short_passing        0.540491
# attacking_volleys              0.610354
# skill_dribbling                0.451210
# skill_curve                    0.443823
# skill_fk_accuracy              0.363007
# skill_long_passing             0.465700
# skill_ball_control             0.541091
# ...

# %%
correlacion_resultados.to_excel(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 2\\correlacion resultados.xlsx', index=True)

# %%
f = plt.figure(figsize=(19, 19))
plt.matshow(normalized_final_4.corr(), fignum=f.number)
plt.xticks(range(normalized_final_4.select_dtypes(['number']).shape[1]), normalized_final_4.select_dtypes(['number']).columns, fontsize=14, rotation=90)
plt.yticks(range(normalized_final_4.select_dtypes(['number']).shape[1]), normalized_final_4.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Matriz de Correlación - Dimensiones futbolísticas vs Resultados Mundial Qatar 2022', fontsize=20);

# %%
final_3['club_name']
# Out:
# 0        Paris Saint-Germain
# 1          FC Bayern München
# 2          Manchester United
# 6        Paris Saint-Germain
# 9          Tottenham Hotspur
#                 ...
# 17765       Grenoble Foot 38
# 18521              FC Luzern
# 18584          Longford Town
# 18645      Scunthorpe United
# 18663         Fleetwood Town
# Name: club_name, Length: 400, dtype: object

# %%
final_max = final_3.groupby(['Equipo nacional','Resultado final'])[['overall','potential','value_eur','wage_eur','age','height_cm','weight_kg',
                'pace',
                 'shooting',
                 'passing',
                 'dribbling',
                 'defending',
                 'physic',
                 'attacking_crossing',
                 'attacking_finishing',
                 'attacking_heading_accuracy',
                 'attacking_short_passing',
                 'attacking_volleys',
                 'skill_dribbling',
                 'skill_curve',
                 'skill_fk_accuracy',
                 'skill_long_passing',
                 'skill_ball_control',
                 'movement_acceleration',
                 'movement_sprint_speed',
                 'movement_agility',
                 'movement_reactions',
                 'movement_balance',
                 'power_shot_power',
                 'power_jumping',
                 'power_stamina',
                 'power_strength',
                 'power_long_shots',
                 'mentality_aggression',
                 'mentality_interceptions',
                 'mentality_positioning',
                 'mentality_vision',
                 'mentality_penalties',
                 'mentality_composure',
                 'defending_marking_awareness',
                 'defending_standing_tackle',
                 'defending_sliding_tackle',
                 'goalkeeping_diving',
                 'goalkeeping_handling',
                 'goalkeeping_kicking',
                 'goalkeeping_positioning',
                 'goalkeeping_reflexes',
                 'goalkeeping_speed','Resultado numerico','Resultado final']].max()

# %%
final_max
# Out:
#                                  overall  potential    value_eur  wage_eur  \
# Equipo nacional Resultado final
# Argentina       Campeon               93         93   93000000.0  320000.0
# Australia       Octavofinalista       77         79   10000000.0   52000.0
# Brazil          Cuartofinalista       89         91   94000000.0  310000.0
# Croatia         Semifinalista         87         87   41500000.0  190000.0
# England         Cuartofinalista       90         92  129500000.0  290000.0
# France          Subcampeon            91         95  194000000.0  350000.0
# Japan           Octavofinalista       79         88   24000000.0   84000.0
# Korea Republic  Octavofinalista       76         81    8000000.0   58000.0
# Morocco         Semifinalista         85         88   69500000.0  170000.0
# Netherlands     Cuartofinalista       89         92  119500000.0  230000.0
# Poland          Octavofinalista       92         92  119500000.0  270000.0
# ...

# %%
f = plt.figure(figsize=(19, 19))
plt.matshow(final_max.corr(), fignum=f.number)
plt.xticks(range(final_max.select_dtypes(['number']).shape[1]), final_max.select_dtypes(['number']).columns, fontsize=14, rotation=90)
plt.yticks(range(final_max.select_dtypes(['number']).shape[1]), final_max.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Matriz de Correlación (Máximos) - Resultados Mundial Qatar 2022', fontsize=20);

# %%
correlacion_resultados_max = final_max[final_max.columns[2:]].corr()['Resultado numerico']
correlacion_resultados_max
# Out:
# value_eur                      0.501146
# wage_eur                       0.646987
# age                            0.164335
# height_cm                     -0.024503
# weight_kg                      0.025829
# pace                           0.114997
# shooting                       0.548174
# passing                        0.700092
# dribbling                      0.748413
# defending                      0.349348
# physic                         0.097394
# attacking_crossing             0.617886
# attacking_finishing            0.582897
# attacking_heading_accuracy     0.372621
# attacking_short_passing        0.630266
# attacking_volleys              0.506636
# skill_dribbling                0.740937
# skill_curve                    0.749795
# skill_fk_accuracy              0.718969
# skill_long_passing             0.619332
# skill_ball_control             0.762475
# movement_acceleration          0.238865
# movement_sprint_speed          0.133479
# ...

# %%
correlacion_resultados_max.to_excel(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 2\\correlacion resultados_max.xlsx', index=True)

# %%
final_min = final_3.groupby(['Equipo nacional','Resultado final'])[['overall','potential','value_eur','wage_eur','age','height_cm','weight_kg',
                'pace',
                 'shooting',
                 'passing',
                 'dribbling',
                 'defending',
                 'physic',
                 'attacking_crossing',
                 'attacking_finishing',
                 'attacking_heading_accuracy',
                 'attacking_short_passing',
                 'attacking_volleys',
                 'skill_dribbling',
                 'skill_curve',
                 'skill_fk_accuracy',
                 'skill_long_passing',
                 'skill_ball_control',
                 'movement_acceleration',
                 'movement_sprint_speed',
                 'movement_agility',
                 'movement_reactions',
                 'movement_balance',
                 'power_shot_power',
                 'power_jumping',
                 'power_stamina',
                 'power_strength',
                 'power_long_shots',
                 'mentality_aggression',
                 'mentality_interceptions',
                 'mentality_positioning',
                 'mentality_vision',
                 'mentality_penalties',
                 'mentality_composure',
                 'defending_marking_awareness',
                 'defending_standing_tackle',
                 'defending_sliding_tackle',
                 'goalkeeping_diving',
                 'goalkeeping_handling',
                 'goalkeeping_kicking',
                 'goalkeeping_positioning',
                 'goalkeeping_reflexes',
                 'goalkeeping_speed','Resultado numerico','Resultado final']].min()

# %%
final_min
# Out:
#                                  overall  potential  value_eur  wage_eur  age  \
# Equipo nacional Resultado final
# Argentina       Campeon               59         65   350000.0     500.0   20
# Australia       Octavofinalista       63         67   475000.0     500.0   19
# Brazil          Cuartofinalista       62         67   550000.0     500.0   19
# Croatia         Semifinalista         64         73  1300000.0     500.0   18
# England         Cuartofinalista       53         63   240000.0     500.0   18
# France          Subcampeon            62         75   850000.0     850.0   18
# Japan           Octavofinalista       58         61   110000.0     500.0   20
# Korea Republic  Octavofinalista       65         69   925000.0    1000.0   21
# Morocco         Semifinalista         56         64   325000.0    1000.0   18
# Netherlands     Cuartofinalista       60         67   500000.0     500.0   18
# Poland          Octavofinalista       63         70   750000.0     750.0   19
# ...

# %%
f = plt.figure(figsize=(19, 19))
plt.matshow(final_min.corr(), fignum=f.number)
plt.xticks(range(final_min.select_dtypes(['number']).shape[1]), final_min.select_dtypes(['number']).columns, fontsize=14, rotation=90)
plt.yticks(range(final_min.select_dtypes(['number']).shape[1]), final_min.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Matriz de Correlación (Mínimos) - Resultados Mundial Qatar 2022', fontsize=20);

# %%
correlacion_resultados_min = final_min[final_min.columns[2:]].corr()['Resultado numerico']
correlacion_resultados_min
# Out:
# value_eur                      0.169479
# wage_eur                       0.087975
# age                            0.073065
# height_cm                      0.189393
# weight_kg                      0.083605
# pace                           0.169604
# shooting                       0.136156
# passing                        0.105932
# dribbling                      0.108315
# defending                      0.097305
# physic                         0.095088
# attacking_crossing             0.136524
# attacking_finishing           -0.066563
# attacking_heading_accuracy    -0.007830
# attacking_short_passing        0.015686
# attacking_volleys             -0.086592
# skill_dribbling                0.102144
# skill_curve                   -0.007474
# skill_fk_accuracy              0.320000
# skill_long_passing             0.140898
# skill_ball_control            -0.303085
# movement_acceleration          0.233039
# movement_sprint_speed          0.266572
# ...

# %%
correlacion_resultados_min.to_excel(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 2\\correlacion resultados_min.xlsx', index=True)

# %%
max_dribbling = final_3.groupby(['Equipo nacional'])['dribbling'].nlargest(5)
max_vision = final_3.groupby(['Equipo nacional'])['mentality_vision'].nlargest(5)
max_control = final_3.groupby(['Equipo nacional'])['skill_ball_control'].nlargest(5)

# %%
print(max_dribbling.to_string())
print(max_vision.to_string())
print(max_control.to_string())
# Out:
# Equipo nacional
# Argentina        0       95.0
#                  41      90.0
#                  33      87.0
#                  135     87.0
#                  93      85.0
# Australia        1528    76.0
#                  914     75.0
#                  5134    74.0
#                  1286    73.0
#                  2658    73.0
# Brazil           272     84.0
#                  664     84.0
#                  702     84.0
#                  269     83.0
#                  658     83.0
# Croatia          32      88.0
#                  173     88.0
#                  180     86.0
#                  1441    83.0
#                  505     82.0
# England          119     88.0
#                  27      87.0
#                  140     87.0
#                  95      84.0
#                  253     84.0
# France           6       92.0
#                  64      88.0
#                  11      87.0
#                  83      87.0
#                  193     86.0
# ...

# %%
max_dribbling.groupby(['Equipo nacional']).mean()
# Out:
# Equipo nacional
# Argentina         88.8
# Australia         74.2
# Brazil            83.6
# Croatia           85.4
# England           86.0
# France            88.0
# Japan             80.6
# Korea Republic    76.0
# Morocco           79.2
# Netherlands       83.6
# Poland            79.0
# Portugal          87.6
# Senegal           78.2
# Spain             82.6
# Switzerland       78.8
# United States     80.2
# Name: dribbling, dtype: float64

# %%
skill_ball_control

# %%
max_vision.groupby(['Equipo nacional']).mean()
# Out:
# Equipo nacional
# Argentina         88.0
# Australia         71.8
# Brazil            78.0
# Croatia           82.8
# England           86.0
# France            82.6
# Japan             77.0
# Korea Republic    73.6
# Morocco           78.2
# Netherlands       82.8
# Poland            75.8
# Portugal          84.8
# Senegal           70.0
# Spain             84.4
# Switzerland       77.0
# United States     76.2
# Name: mentality_vision, dtype: float64

# %%
max_control.groupby(['Equipo nacional']).mean()
# Out:
# Equipo nacional
# Argentina         89.8
# Australia         73.8
# Brazil            83.8
# Croatia           86.8
# England           86.8
# France            88.4
# Japan             80.2
# Korea Republic    76.2
# Morocco           81.6
# Netherlands       84.8
# Poland            81.6
# Portugal          87.8
# Senegal           78.4
# Spain             84.8
# Switzerland       79.8
# United States     78.4
# Name: skill_ball_control, dtype: float64

# %%
max_5 = pd.read_excel(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 2\\Max 5.xlsx')
max_5
# Out:
#    Equipo nacional  Dribbling  Vision  Control  Resultado final  \
# 0        Argentina       88.8    88.0     89.8          Campeon
# 1        Australia       74.2    71.8     73.8  Octavofinalista
# 2           Brazil       83.6    78.0     83.8  Cuartofinalista
# 3          Croatia       85.4    82.8     86.8    Semifinalista
# 4          England       86.0    86.0     86.8  Cuartofinalista
# 5           France       88.0    82.6     88.4       Subcampeon
# 6            Japan       80.6    77.0     80.2  Octavofinalista
# 7   Korea Republic       76.0    73.6     76.2  Octavofinalista
# 8          Morocco       79.2    78.2     81.6    Semifinalista
# 9      Netherlands       83.6    82.8     84.8  Cuartofinalista
# 10          Poland       79.0    75.8     81.6  Octavofinalista
# 11        Portugal       87.6    84.8     87.8  Cuartofinalista
# 12         Senegal       78.2    70.0     78.4  Octavofinalista
# 13           Spain       82.6    84.4     84.8  Octavofinalista
# ...

# %%
f = plt.figure(figsize=(19, 19))
plt.matshow(max_5.corr(), fignum=f.number)
plt.xticks(range(max_5.select_dtypes(['number']).shape[1]), max_5.select_dtypes(['number']).columns, fontsize=20, rotation=90)
plt.yticks(range(max_5.select_dtypes(['number']).shape[1]), max_5.select_dtypes(['number']).columns, fontsize=20)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Matriz de Correlación (5 Máximos valores) - Resultados Mundial Qatar 2022', fontsize=20);

# %%
correlacion_resultados_max_5 = max_5.corr()['Resultado numerico']
correlacion_resultados_max_5
# Out:
# Dribbling             0.727906
# Vision                0.646972
# Control               0.738775
# Resultado numerico    1.000000
# Name: Resultado numerico, dtype: float64

# %%
final_3.groupby(['league_name'])['Resultado numerico'].mean().sort_values(ascending=False)
# Out:
# league_name
# Argentina Primera División              5.000000
# Uruguayan Primera División              5.000000
# Colombian Liga Postobón                 5.000000
# Ecuadorian Serie A                      3.666667
# Croatian Prva HNL                       3.000000
# Saudi Abdul L. Jameel League            3.000000
# Venezuelan Primera División             3.000000
# Mexican Liga MX                         2.500000
# French Ligue 1                          2.500000
# Italian Serie A                         2.454545
# Spain Primera Division                  2.348837
# Portuguese Liga ZON SAGRES              2.300000
# Holland Eredivisie                      2.285714
# English Premier League                  2.014925
# French Ligue 2                          2.000000
# Paraguayan Primera División             2.000000
# German 3. Bundesliga                    2.000000
# Cypriot First Division                  2.000000
# German 1. Bundesliga                    1.875000
# ...

# %%
print(final_3.groupby(['club_name'])['Resultado numerico'].mean().sort_values(ascending=False).to_string())
# Out:
# club_name
# Barcelona Sporting Club             5.000000
# River Plate                         5.000000
# Deportivo Cali                      5.000000
# Brighton & Hove Albion              5.000000
# Gallos Blancos de Querétaro         5.000000
# Vélez Sarsfield                     5.000000
# Club Atlético Banfield              5.000000
# Aragua Fútbol Club                  5.000000
# Udinese Calcio                      5.000000
# Montevideo City Torque              5.000000
# Sevilla FC                          4.250000
# Le Havre AC                         4.000000
# FC Nantes                           4.000000
# Inter                               3.600000
# SL Benfica                          3.500000
# Bayer 04 Leverkusen                 3.500000
# FC Bayern München                   3.200000
# Fiorentina                          3.000000
# Tottenham Hotspur                   3.000000
# TSG Hoffenheim                      3.000000
# Dinamo Zagreb                       3.000000
# ...

# %%
final_3_excel = final_3[['Resultado final','club_name','league_name','Equipo nacional']]
final_3_excel
# Out:
#        Resultado final            club_name                     league_name  \
# 0              Campeon  Paris Saint-Germain                  French Ligue 1
# 1      Octavofinalista    FC Bayern München            German 1. Bundesliga
# 2      Cuartofinalista    Manchester United          English Premier League
# 6           Subcampeon  Paris Saint-Germain                  French Ligue 1
# 9      Cuartofinalista    Tottenham Hotspur          English Premier League
# ...                ...                  ...                             ...
# 17765    Semifinalista     Grenoble Foot 38                  French Ligue 2
# 18521  Octavofinalista            FC Luzern              Swiss Super League
# 18584  Octavofinalista        Longford Town  Rep. Ireland Airtricity League
# 18645  Cuartofinalista    Scunthorpe United              English League Two
# 18663  Octavofinalista       Fleetwood Town              English League One
#
#       Equipo nacional
# 0           Argentina
# ...

# %%
final_3_excel.to_excel(r'C:\Users\moral\Documents\Master Ciencia de Datos\Semestre 4\Visualizacion de datos\PRA 2\\final_3_excel.xlsx', index=False)

# %%
final_3.columns.to_list()
# Out:
# ['short_name',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'age',
#  'height_cm',
#  'weight_kg',
#  'league_name',
#  'nationality_name',
#  'pace',
#  'club_name',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
#  'skill_ball_control',
#  'movement_acceleration',
#  'movement_sprint_speed',
#  'movement_agility',
#  'movement_reactions',
#  'movement_balance',
#  'power_shot_power',
#  'power_jumping',
#  'power_stamina',
#  'power_strength',
#  'power_long_shots',
#  'mentality_aggression',
#  'mentality_interceptions',
#  'mentality_positioning',
#  'mentality_vision',
#  'mentality_penalties',
#  'mentality_composure',
#  'defending_marking_awareness',
#  'defending_standing_tackle',
# ...
